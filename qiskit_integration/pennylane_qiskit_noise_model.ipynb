# %%
from qiskit.providers.fake_provider import FakeManila
from qiskit_aer.noise import NoiseModel

import pennylane as qml

import json


# Make a noise model from a fake device
fake_backend = FakeManila()
noise_model = NoiseModel.from_backend(fake_backend)

# %%
# Create a PennyLane device
dev = qml.device('qiskit.aer', wires=2, noise_model=noise_model)

# Create a PennyLane quantum node run on the device
@qml.qnode(dev)
def circuit(x, y, z):
    qml.RZ(z, wires=[0])
    qml.RY(y, wires=[0])
    qml.RX(x, wires=[0])
    qml.CNOT(wires=[0, 1])
    return qml.expval(qml.PauliZ(wires=1))

# Result of noisy simulator
print(circuit(0.2, 0.1, 0.3))
# Out:
# 0.922

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService()

service.backends()
# Out:
# [<IBMBackend('ibm_perth')>,
#  <IBMBackend('ibmq_qasm_simulator')>,
#  <IBMBackend('ibmq_lima')>,
#  <IBMBackend('simulator_stabilizer')>,
#  <IBMBackend('simulator_mps')>,
#  <IBMBackend('simulator_statevector')>,
#  <IBMBackend('ibmq_manila')>,
#  <IBMBackend('ibm_nairobi')>,
#  <IBMBackend('ibm_lagos')>,
#  <IBMBackend('ibmq_quito')>,
#  <IBMBackend('ibmq_belem')>,
#  <IBMBackend('simulator_extended_stabilizer')>,
#  <IBMBackend('ibmq_jakarta')>]

# %%
backend = service.get_backend("ibm_lagos")

noise_model_real = NoiseModel.from_backend(backend, thermal_relaxation=False)

# %%
# Create a PennyLane device
dev = qml.device('qiskit.aer', wires=2, noise_model=noise_model_real)

# Create a PennyLane quantum node run on the device
@qml.qnode(dev)
def circuit(x, y, z):
    qml.RZ(z, wires=[0])
    qml.RY(y, wires=[0])
    qml.RX(x, wires=[0])
    qml.CNOT(wires=[0, 1])
    return qml.expval(qml.PauliZ(wires=1))

# Result of noisy simulator
print(circuit(0.2, 0.1, 0.3))
# Out:
# 0.918

# %%
noise_model_real.to_dict()
# Out:
# {'errors': [{'type': 'qerror',
#    'id': '6ef7f5751c2946f2a8de308e640260e9',
#    'operations': ['id'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [0.9992984086909883,
#     0.00023386376967057882,
#     0.00023386376967057882,
#     0.00023386376967057882],
#    'gate_qubits': [(0,)]},
#   {'type': 'qerror',
#    'id': 'e79307cdc87f497a8fc56b843a316d8b',
#    'operations': ['id'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [0.9995834288310265,
#     0.00013885705632452514,
#     0.00013885705632452514,
#     0.00013885705632452514],
#    'gate_qubits': [(1,)]},
#   {'type': 'qerror',
#    'id': '95d649a781bd4c1db56c7033852dbf41',
#    'operations': ['id'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [0.9991474377080735,
#     0.00028418743064218606,
#     0.00028418743064218606,
#     0.00028418743064218606],
#    'gate_qubits': [(2,)]},
#   {'type': 'qerror',
#    'id': '0b045da6fa074a25938164b4c73bd2f2',
#    'operations': ['id'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'id', 'qubits': [0]}],
#     [{'name': 'id', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'id', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]}, {'name': 'id', 'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]}, {'name': 'id', 'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}, {'name': 'id', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}]],
#    'probabilities': [0.9995463333707588,
#     2.877570840898577e-05,
#     0.0002898486170542094,
#     4.49997567346019e-05,
#     1.2954875977618983e-09,
#     1.3049037170007966e-08,
#     4.49997567346019e-05,
#     1.2954875977618983e-09,
#     1.3049037170007966e-08,
#     4.49997567346019e-05,
#     1.2954875977618983e-09,
#     1.3049037170007966e-08],
#    'gate_qubits': [(3,)]},
#   {'type': 'qerror',
#    'id': 'a78cdf8955e342bd86a100dbe0481126',
#    'operations': ['id'],
#    'instructions': [[{'name': 'kraus',
#       'params': [array([[-0.99985102+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99889829+0.j]]),
#        array([[-0.01726113+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0172776 +0.j]]),
#        array([[0.        +0.j, 0.04363121+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [1.0],
#    'gate_qubits': [(4,)]},
#   {'type': 'qerror',
#    'id': 'c916e35da99645bfa2f1867014e15309',
#    'operations': ['sx'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [0.9992984086909883,
#     0.00023386376967057882,
#     0.00023386376967057882,
#     0.00023386376967057882],
#    'gate_qubits': [(0,)]},
#   {'type': 'qerror',
#    'id': '48dc1b089057435d81f2fd372c2f6a98',
#    'operations': ['sx'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [0.9995834288310265,
#     0.00013885705632452514,
#     0.00013885705632452514,
#     0.00013885705632452514],
#    'gate_qubits': [(1,)]},
#   {'type': 'qerror',
#    'id': '7d6fa1769e3244e88452e981baef0482',
#    'operations': ['sx'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [0.9991474377080735,
#     0.00028418743064218606,
#     0.00028418743064218606,
#     0.00028418743064218606],
#    'gate_qubits': [(2,)]},
#   {'type': 'qerror',
#    'id': '7121091d9762482ea709d66c9dc36381',
#    'operations': ['sx'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'id', 'qubits': [0]}],
#     [{'name': 'id', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'id', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]}, {'name': 'id', 'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]}, {'name': 'id', 'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}, {'name': 'id', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}]],
#    'probabilities': [0.9995463333707588,
#     2.877570840898577e-05,
#     0.0002898486170542094,
#     4.49997567346019e-05,
#     1.2954875977618983e-09,
#     1.3049037170007966e-08,
#     4.49997567346019e-05,
#     1.2954875977618983e-09,
#     1.3049037170007966e-08,
#     4.49997567346019e-05,
#     1.2954875977618983e-09,
#     1.3049037170007966e-08],
#    'gate_qubits': [(3,)]},
#   {'type': 'qerror',
#    'id': '1c576ab18f91473b9f2726867148e2ad',
#    'operations': ['sx'],
#    'instructions': [[{'name': 'kraus',
#       'params': [array([[-0.99985102+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99889829+0.j]]),
#        array([[-0.01726113+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0172776 +0.j]]),
#        array([[0.        +0.j, 0.04363121+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [1.0],
#    'gate_qubits': [(4,)]},
#   {'type': 'qerror',
#    'id': '0ace10c7db0f41dcb3da3b3d912d3ec6',
#    'operations': ['x'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99998958+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99987368+0.j]]),
#        array([[-0.00456412+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00456465+0.j]]),
#        array([[0.        +0.j, 0.01522432+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [0.9992984086909883,
#     0.00023386376967057882,
#     0.00023386376967057882,
#     0.00023386376967057882],
#    'gate_qubits': [(0,)]},
#   {'type': 'qerror',
#    'id': 'ca94c09359844a6a9eb8b2a2fccb0786',
#    'operations': ['x'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997005+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99983474+0.j]]),
#        array([[-0.00773934+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00774039+0.j]]),
#        array([[0.       +0.j, 0.0164491+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [0.9995834288310265,
#     0.00013885705632452514,
#     0.00013885705632452514,
#     0.00013885705632452514],
#    'gate_qubits': [(1,)]},
#   {'type': 'qerror',
#    'id': '874808e5cd3a402c9ee2638bdc0f3bc3',
#    'operations': ['x'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.9999973 +0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99980981+0.j]]),
#        array([[-0.00232572+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.00232616+0.j]]),
#        array([[0.        +0.j, 0.01936339+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [0.9991474377080735,
#     0.00028418743064218606,
#     0.00028418743064218606,
#     0.00028418743064218606],
#    'gate_qubits': [(2,)]},
#   {'type': 'qerror',
#    'id': '48ec4539f3324247a9db4e60611161ed',
#    'operations': ['x'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'id', 'qubits': [0]}],
#     [{'name': 'id', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'id', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]}, {'name': 'id', 'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'x', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]}, {'name': 'id', 'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'y', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}, {'name': 'id', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}, {'name': 'z', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}, {'name': 'reset', 'qubits': [0]}]],
#    'probabilities': [0.9995463333707588,
#     2.877570840898577e-05,
#     0.0002898486170542094,
#     4.49997567346019e-05,
#     1.2954875977618983e-09,
#     1.3049037170007966e-08,
#     4.49997567346019e-05,
#     1.2954875977618983e-09,
#     1.3049037170007966e-08,
#     4.49997567346019e-05,
#     1.2954875977618983e-09,
#     1.3049037170007966e-08],
#    'gate_qubits': [(3,)]},
#   {'type': 'qerror',
#    'id': '8c0fc5950d6b417186ee77b798f46e06',
#    'operations': ['x'],
#    'instructions': [[{'name': 'kraus',
#       'params': [array([[-0.99985102+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99889829+0.j]]),
#        array([[-0.01726113+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0172776 +0.j]]),
#        array([[0.        +0.j, 0.04363121+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [1.0],
#    'gate_qubits': [(4,)]},
#   {'type': 'qerror',
#    'id': '6a0daf17695d4b0c86fa30e454b95b64',
#    'operations': ['cx'],
#    'instructions': [[{'name': 'kraus',
#       'params': [array([[-0.99802805+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.98507555+0.j]]),
#        array([[-0.06276959+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.06359493+0.j]]),
#        array([[0.        +0.j, 0.15994326+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'id', 'qubits': [1]}],
#     [{'name': 'kraus',
#       'params': [array([[-0.99802805+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.98507555+0.j]]),
#        array([[-0.06276959+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.06359493+0.j]]),
#        array([[0.        +0.j, 0.15994326+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'z', 'qubits': [1]}],
#     [{'name': 'kraus',
#       'params': [array([[-0.99802805+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.98507555+0.j]]),
#        array([[-0.06276959+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.06359493+0.j]]),
#        array([[0.        +0.j, 0.15994326+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'reset', 'qubits': [1]}]],
#    'probabilities': [0.9956748846176906,
#     0.0003898338368381378,
#     0.003935281545471292],
#    'gate_qubits': [(4, 3)]},
#   {'type': 'qerror',
#    'id': '3ff2ea3e20a84687a6f7de318630b7fd',
#    'operations': ['cx'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99788765+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.98398314+0.j]]),
#        array([[-0.06496337+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.06588136+0.j]]),
#        array([[0.        +0.j, 0.16564067+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99788765+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.98398314+0.j]]),
#        array([[-0.06496337+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.06588136+0.j]]),
#        array([[0.        +0.j, 0.16564067+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'reset', 'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99788765+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.98398314+0.j]]),
#        array([[-0.06496337+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.06588136+0.j]]),
#        array([[0.        +0.j, 0.16564067+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}]],
#    'probabilities': [0.9953576067510093,
#     0.0004183647293221853,
#     0.004224028519668521],
#    'gate_qubits': [(3, 4)]},
#   {'type': 'qerror',
#    'id': 'f8d0d0c952fe463ba082bec0654163ca',
#    'operations': ['cx'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'id', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'id', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'id', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99991059+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99891405+0.j]]),
#        array([[-0.01337178+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01338512+0.j]]),
#        array([[0.       +0.j, 0.0446268+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99974306+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99857921+0.j]]),
#        array([[-0.02266769+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0226941 +0.j]]),
#        array([[0.        +0.j, 0.04821343+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}]],
#    'probabilities': [0.9936745285916612,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763,
#     0.0004216980938892763],
#    'gate_qubits': [(0, 1)]},
#   {'type': 'qerror',
#    'id': '0416e94ce30446438cbdd6bf84556411',
#    'operations': ['cx'],
#    'instructions': [[{'name': 'id', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'id', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'id', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'id', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99878784+0.j]]),
#        array([[-0.01412605+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.01414178+0.j]]),
#        array([[0.        +0.j, 0.04714732+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971327+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99841407+0.j]]),
#        array([[-0.02394538+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02397654+0.j]]),
#        array([[0.        +0.j, 0.05093603+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99990022+0.j,  0.        +0.j],
# ...
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'id', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'id', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'id', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'x', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'y', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'id', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'x', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'y', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}],
#     [{'name': 'z', 'qubits': [0]},
#      {'name': 'z', 'qubits': [1]},
#      {'name': 'kraus',
#       'params': [array([[-0.99971922+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99844709+0.j]]),
#        array([[-0.02369542+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.02372561+0.j]]),
#        array([[0.        +0.j, 0.05040333+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]},
#      {'name': 'kraus',
#       'params': [array([[-0.99997466+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.99821352+0.j]]),
#        array([[-0.00711914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.0071317 +0.j]]),
#        array([[0.       +0.j, 0.0593203+0.j],
#               [0.       +0.j, 0.       +0.j]])],
#       'qubits': [1]}]],
#    'probabilities': [0.9952514696800066,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036,
#     0.00031656868799958036],
#    'gate_qubits': [(1, 2)]},
#   {'type': 'qerror',
#    'id': 'a8c8bd335ef84bef99cadbe2a3fdebb4',
#    'operations': ['reset'],
#    'instructions': [[{'name': 'kraus',
#       'params': [array([[-0.99823322+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.9777802 +0.j]]),
#        array([[-0.05941751+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.06066039+0.j]]),
#        array([[0.        +0.j, 0.20066438+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [1.0],
#    'gate_qubits': [(0,)]},
#   {'type': 'qerror',
#    'id': 'a7bac46670eb4c76b87673f459328dd8',
#    'operations': ['reset'],
#    'instructions': [[{'name': 'kraus',
#       'params': [array([[-0.99498355+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.97089821+0.j]]),
#        array([[-0.10003869+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.10252038+0.j]]),
#        array([[0.        +0.j, 0.21643993+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [1.0],
#    'gate_qubits': [(1,)]},
#   {'type': 'qerror',
#    'id': 'b90e643933e84ee895f58252a1c00fdf',
#    'operations': ['reset'],
#    'instructions': [[{'name': 'kraus',
#       'params': [array([[-0.99955202+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.96680677+0.j]]),
#        array([[-0.02992914+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.03094282+0.j]]),
#        array([[0.        +0.j, 0.25362811+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [1.0],
#    'gate_qubits': [(2,)]},
#   {'type': 'qerror',
#    'id': '1e4c7ccf56c0420c946d96863ab2307c',
#    'operations': ['reset'],
#    'instructions': [[{'name': 'id', 'qubits': [0]}],
#     [{'name': 'z', 'qubits': [0]}],
#     [{'name': 'reset', 'qubits': [0]}]],
#    'probabilities': [0.9480860448437302,
#     0.004566289380833261,
#     0.04734766577543659],
#    'gate_qubits': [(3,)]},
#   {'type': 'qerror',
#    'id': '406c54a632474753aca864952e337351',
#    'operations': ['reset'],
#    'instructions': [[{'name': 'kraus',
#       'params': [array([[-0.98284233+0.j,  0.        +0.j],
#               [ 0.        +0.j, -0.81473789+0.j]]),
#        array([[-0.18444772+0.j,  0.        +0.j],
#               [ 0.        +0.j,  0.22250472+0.j]]),
#        array([[0.        +0.j, 0.53543798+0.j],
#               [0.        +0.j, 0.        +0.j]])],
#       'qubits': [0]}]],
#    'probabilities': [1.0],
#    'gate_qubits': [(4,)]},
#   {'type': 'roerror',
#    'operations': ['measure'],
#    'probabilities': [[0.9826999999999999, 0.017300000000000093],
#     [0.017300000000000093, 0.9826999999999999]],
#    'gate_qubits': [(0,)]},
#   {'type': 'roerror',
#    'operations': ['measure'],
#    'probabilities': [[0.9783999999999999, 0.021600000000000064],
#     [0.021600000000000064, 0.9783999999999999]],
#    'gate_qubits': [(1,)]},
#   {'type': 'roerror',
#    'operations': ['measure'],
#    'probabilities': [[0.9794, 0.02059999999999995],
#     [0.02059999999999995, 0.9794]],
#    'gate_qubits': [(2,)]},
#   {'type': 'roerror',
#    'operations': ['measure'],
#    'probabilities': [[0.9678, 0.032200000000000006],
#     [0.032200000000000006, 0.9678]],
#    'gate_qubits': [(3,)]},
#   {'type': 'roerror',
#    'operations': ['measure'],
#    'probabilities': [[0.9568, 0.043200000000000016],
#     [0.043200000000000016, 0.9568]],
#    'gate_qubits': [(4,)]}]}
